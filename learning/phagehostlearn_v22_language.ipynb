# %% [markdown]
# # PhageHostLearn - v2.2 (Klebsiella)
#
# An AI-based Phage-Host interaction predictor framework with K-loci and receptor-binding proteins at its core. This particular PhageHostLearn is for *Klebsiella pneumoniae* related phages. This notebook follows after having ran the PhageHostLearn_processing steps implemented in the accompanying Jupyter notebook.
#
# **Architecture of this framework**:
# - Multi-RBP setting: phages consisting of one or more RBPs (multi-instance)
# - K-loci proteins (multi-instance)
# - Embeddings for both that are concatenated
# - Train an XGBoost and RF model on the concatenated embeddings (binary classification)
#
# **Overview of the notebook**:
#
# 1. [Transform the loci proteins into embeddings](#locusembed)
# 2. [Transform the RBP sequences into embeddings](#rbpembed)
# 3. Constructing a dataframe for training models
# 4. [Concatenate and train an XGBoost and RF models](#models)

# %% [markdown]
# ## 0 - Libraries and directories

# %%
import os
import math
import json
#import umap
import random
import subprocess
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from tqdm.notebook import tqdm
from Bio import SeqIO
from xgboost import XGBClassifier
from scipy.stats import spearmanr
from Bio.Blast import NCBIWWW, NCBIXML
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from Bio.Blast.Applications import NcbiblastpCommandline
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split, LeaveOneGroupOut
from sklearn.metrics import make_scorer, f1_score, roc_auc_score, auc, precision_recall_curve, average_precision_score, confusion_matrix
#from bio_embeddings.embed import Word2VecEmbedder, ProtTransBertBFDEmbedder, SeqVecEmbedder
# %matplotlib inline

# %%
# set project directory (to locate Kaptive), data directory and results directory
project_dir = '/Users/dimi/Documents/GitHub_Local/PhageHostLearning'
valencia_dir = '/Users/dimi/GoogleDrive/PhD/4_PHAGEHOST_LEARNING/42_DATA/Valencia_data' # general directory
data_suffix = 'Valencia' # choose a suffix for the created data files
results_dir = '/Users/dimi/GoogleDrive/PhD/4_PHAGEHOST_LEARNING/43_RESULTS/models'
cdpath = '/Users/dimi/cd-hit-v4.8.1-2019-0228'

# %% [markdown]
# ## 1 - Transform locus into embeddings<a name="locusembed"></a>

# %%
def loci_protein_embeddings(dict_path, results_dir):
    """
    This function computes ProtTransBertBFD embeddings for loci proteins in a dictionary (as json). It uses 
    the bio-embeddings package together with BioPython.
    
    WARNING: running this on a personal laptop without GPU can be slow (not advised). Best to start a Google
    Colab notebook and run the computations in the cloud.
    
    Input:
    - jason_dict: path to dictionary (json file) containing the accessions as keys and proteins as values
    - results_dir: path to dir to store embeddings
    Output:
    - an embeddings file with 1 resulting embedding per accession (= multi-instance)
    """
    
    # Load json file
    dict_file = open(dict_path)
    loci_dict = json.load(dict_file)
    
    # compute embeddings
    embedder = ProtTransBertBFDEmbedder()
    embeddings_list = [] # store locus embeddings
    for key in tqdm(loci_dict.keys()):
        embeddings = [embedder.reduce_per_protein(embedder.embed(sequence)) for sequence in tqdm(loci_dict[key])]
        locus_emb_matrix = np.vstack(embeddings)
        locus_embedding = np.mean(locus_emb_matrix, axis=0)
        embeddings_list.append(locus_embedding)
        
    embeddings_df = pd.concat([pd.DataFrame({'accession':list(loci_dict.keys())}), pd.DataFrame(embeddings_list)], axis=1)
    embeddings_df.to_csv(results_dir+'/loci_embeddings.csv', index=False)
    
    return

# %%
#json_file = valencia_dir+'/LociBaseValencia.json'
#loci_protein_embeddings(json_file, '')

# %% [markdown]
# ## 2 - Tranform RBP sequences into embeddings <a name="rbpembed"></a>

# %%
def RBP_embeddings(RBPbase, results_dir):
    """
    This function computes embeddings for RBPs in a pandas dataframe.
    """
    embedder = ProtTransBertBFDEmbedder()
    embeddings = [embedder.reduce_per_protein(embedder.embed(sequence)) for sequence in tqdm(RBPbase['protein_sequence'])]
    embeddings_df = pd.concat([pd.DataFrame({'protein_ID':list(RBPbase['protein_ID'])}), pd.DataFrame(embeddings)], axis=1)
    embeddings_df.to_csv(results_dir+'/RBP_embeddings.csv', index=False)
    return

# %%
#RBPbase = pd.read_csv(valencia_dir+'/RBPbase'+data_suffix+'.csv')
#RBP_embeddings(RBPbase, results_dir) # do in Google Colab or Kaggle

# %% [markdown]
# Alternatively, we can subselect previously computed embeddings (for RBP detection step)

# %%
phage_protein_embeddings = pd.read_csv(valencia_dir+'/phage_proteinsValencia_embeddings.csv')
RBPbase = pd.read_csv(valencia_dir+'/RBPbase'+data_suffix+'.csv')

to_delete = []
for i, protein_id in enumerate(phage_protein_embeddings['ID']):
    if protein_id not in list(RBPbase['protein_ID']):
        to_delete.append(i)
        
RBP_embeddings = phage_protein_embeddings.drop(to_delete)
RBP_embeddings = RBP_embeddings.reset_index(drop=True)
RBP_embeddings = pd.concat([RBPbase['phage_ID'], RBP_embeddings], axis=1)
RBP_embeddings.to_csv(valencia_dir+'/RBP_embeddings.csv', index=False)

# %% [markdown]
# ## 3 - Processing into structured dataframe for training at multi-RBP level

# %%
# construct multi-RBP representations
RBP_embeddings = pd.read_csv(valencia_dir+'/RBP_embeddings.csv')

multi_embeddings = []
names = []
for phage_id in list(set(RBP_embeddings['phage_ID'])):
    rbp_embeddings = RBP_embeddings.iloc[:,2:][RBP_embeddings['phage_ID'] == phage_id]
    multi_embedding = np.mean(np.asarray(rbp_embeddings), axis=0)
    names.append(phage_id)
    multi_embeddings.append(multi_embedding)
multiRBP_embeddings = pd.concat([pd.DataFrame({'phage_ID': names}), pd.DataFrame(multi_embeddings)], axis=1)

# %%
# construct dataframe for training
loci_embeddings = pd.read_csv(valencia_dir+'/loci_embeddings.csv')
interactions = pd.read_csv(valencia_dir+'/phage_host_interactionsValencia.csv', index_col=0)
features = []
labels = []
groups = []
for i, accession in enumerate(loci_embeddings['accession']):
    for j, phage_id in enumerate(multiRBP_embeddings['phage_ID']):
        interaction = interactions.loc[accession][phage_id]
        if math.isnan(interaction) == False: # if the interaction is known
            features.append(pd.concat([loci_embeddings.iloc[i, 1:], multiRBP_embeddings.iloc[j, 1:]]))
            labels.append(int(interaction))
            groups.append(i)
features = np.asarray(features)
print("Dimensions match?", features.shape[1] == (loci_embeddings.shape[1]+multiRBP_embeddings.shape[1]-2))
# Out:
# Dimensions match? True

# %% [markdown]
# ## 4 - Building and evaluating machine learning models <a name="models"></a>
#
# Idea is to (1) shuffle data, (2) keep a test set aside, (3) do CV for hyperparameter tuning, (4) plot learning curves with optimized hyperparams and (5) test final performance on test set.

# %% [markdown]
# #### XGBoost

# %%
# shuffle and set test set aside
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, stratify=labels)

# %%
# define model and cross-validation iterator
cpus = 6
imbalance = sum([1 for i in y_train if i ==1]) / sum([1 for i in y_train if i ==0])
xgb = XGBClassifier(scale_pos_weight=1/imbalance, n_jobs=cpus, use_label_encoder=False)
params_xgb = {'max_depth': [3, 5, 7], 'n_estimators': [100, 250, 500, 750], 
              'learning_rate': [0.1, 0.2, 0.3]}
cv = StratifiedKFold(n_splits=5, shuffle=True)

# %%
# do hyperparameter tuning (in GridSearchCV)
tuned_xgb = GridSearchCV(xgb, cv=cv, param_grid=params_xgb, scoring='roc_auc', verbose=3)
tuned_xgb.fit(X_train, y_train, eval_metric='logloss')
print(tuned_xgb.best_params_)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV 1/5] END learning_rate=0.05, max_depth=1, n_estimators=50;, score=0.752 total time=   2.0s
# [CV 2/5] END learning_rate=0.05, max_depth=1, n_estimators=50;, score=0.793 total time=   1.9s
# [CV 3/5] END learning_rate=0.05, max_depth=1, n_estimators=50;, score=0.744 total time=   1.9s
# [CV 4/5] END learning_rate=0.05, max_depth=1, n_estimators=50;, score=0.739 total time=   2.0s
# [CV 5/5] END learning_rate=0.05, max_depth=1, n_estimators=50;, score=0.733 total time=   2.0s
# [CV 1/5] END learning_rate=0.05, max_depth=1, n_estimators=100;, score=0.789 total time=   3.1s
# [CV 2/5] END learning_rate=0.05, max_depth=1, n_estimators=100;, score=0.826 total time=   3.1s
# [CV 3/5] END learning_rate=0.05, max_depth=1, n_estimators=100;, score=0.757 total time=   3.1s
# [CV 4/5] END learning_rate=0.05, max_depth=1, n_estimators=100;, score=0.743 total time=   3.1s
# [CV 5/5] END learning_rate=0.05, max_depth=1, n_estimators=100;, score=0.750 total time=   3.2s
# [CV 1/5] END learning_rate=0.05, max_depth=1, n_estimators=250;, score=0.791 total time=   6.6s
# [CV 2/5] END learning_rate=0.05, max_depth=1, n_estimators=250;, score=0.839 total time=   6.6s
# [CV 3/5] END learning_rate=0.05, max_depth=1, n_estimators=250;, score=0.766 total time=   6.7s
# [CV 4/5] END learning_rate=0.05, max_depth=1, n_estimators=250;, score=0.743 total time=   6.7s
# [CV 5/5] END learning_rate=0.05, max_depth=1, n_estimators=250;, score=0.770 total time=   6.8s
# [CV 1/5] END learning_rate=0.05, max_depth=1, n_estimators=500;, score=0.789 total time=  13.3s
# [CV 2/5] END learning_rate=0.05, max_depth=1, n_estimators=500;, score=0.838 total time=  13.0s
# [CV 3/5] END learning_rate=0.05, max_depth=1, n_estimators=500;, score=0.767 total time=  13.2s
# [CV 4/5] END learning_rate=0.05, max_depth=1, n_estimators=500;, score=0.735 total time=  13.3s
# [CV 5/5] END learning_rate=0.05, max_depth=1, n_estimators=500;, score=0.774 total time=  13.4s
# [CV 1/5] END learning_rate=0.05, max_depth=1, n_estimators=750;, score=0.784 total time=  19.7s
# [CV 2/5] END learning_rate=0.05, max_depth=1, n_estimators=750;, score=0.833 total time=  19.8s
# [CV 3/5] END learning_rate=0.05, max_depth=1, n_estimators=750;, score=0.766 total time=  19.9s
# [CV 4/5] END learning_rate=0.05, max_depth=1, n_estimators=750;, score=0.731 total time=  20.0s
# [CV 5/5] END learning_rate=0.05, max_depth=1, n_estimators=750;, score=0.776 total time=  20.4s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.830 total time=   4.5s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.874 total time=   4.5s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.844 total time=   4.4s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.793 total time=   4.5s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=50;, score=0.827 total time=   4.4s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.840 total time=   7.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.886 total time=   7.7s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.832 total time=   7.7s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.777 total time=   7.7s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=0.838 total time=   7.7s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=250;, score=0.859 total time=  17.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=250;, score=0.891 total time=  17.7s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=250;, score=0.813 total time=  17.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=250;, score=0.771 total time=  18.3s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=250;, score=0.844 total time=  18.2s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=500;, score=0.873 total time=  35.2s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=500;, score=0.890 total time=  35.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=500;, score=0.806 total time=  35.5s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=500;, score=0.774 total time=  35.7s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=500;, score=0.851 total time=  35.8s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=750;, score=0.871 total time=  53.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=750;, score=0.892 total time=  53.4s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=750;, score=0.808 total time=  53.1s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=750;, score=0.777 total time=  53.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=750;, score=0.856 total time=  53.7s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.830 total time=   6.9s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.853 total time=   7.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.860 total time=   6.9s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.794 total time=   6.9s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=50;, score=0.839 total time=   7.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.852 total time=  12.7s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.876 total time=  12.7s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.854 total time=  12.7s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.787 total time=  12.8s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=0.845 total time=  13.7s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=250;, score=0.890 total time=  30.7s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=250;, score=0.885 total time=  30.7s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=250;, score=0.852 total time=  30.4s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=250;, score=0.789 total time=  30.0s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=250;, score=0.850 total time=  30.5s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=500;, score=0.897 total time= 1.0min
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=500;, score=0.881 total time=  59.0s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=500;, score=0.844 total time=  59.4s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=500;, score=0.793 total time= 1.0min
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=500;, score=0.865 total time=  59.3s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=750;, score=0.903 total time= 1.5min
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=750;, score=0.883 total time= 1.5min
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=750;, score=0.841 total time= 1.5min
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=750;, score=0.794 total time= 1.5min
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=750;, score=0.867 total time= 1.6min
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=0.792 total time=   2.7s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=0.828 total time=   2.7s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=0.758 total time=   2.7s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=0.743 total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=0.751 total time=   2.7s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=0.795 total time=   4.2s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=0.839 total time=   4.2s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=0.766 total time=   4.2s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=0.743 total time=   4.2s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=0.764 total time=   4.2s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=250;, score=0.787 total time=   8.9s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=250;, score=0.838 total time=   8.9s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=250;, score=0.765 total time=   8.8s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=250;, score=0.735 total time=   8.8s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=250;, score=0.775 total time=   8.9s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=500;, score=0.774 total time=  16.6s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=500;, score=0.829 total time=  17.5s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=500;, score=0.762 total time=  17.7s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=500;, score=0.731 total time=  16.8s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=500;, score=0.775 total time=  16.7s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=750;, score=0.763 total time=  24.6s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=750;, score=0.824 total time=  25.7s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=750;, score=0.753 total time=  25.2s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=750;, score=0.730 total time=  24.5s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=750;, score=0.774 total time=  24.5s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.845 total time=   5.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.881 total time=   5.3s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.838 total time=   5.2s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.784 total time=   5.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.844 total time=   5.2s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.860 total time=   9.2s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.891 total time=   9.3s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.821 total time=   9.2s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.782 total time=   9.2s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=0.848 total time=   9.2s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.880 total time=  21.3s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.888 total time=  21.2s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.813 total time=  21.2s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.776 total time=  21.4s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=250;, score=0.846 total time=  21.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=500;, score=0.881 total time=  41.5s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=500;, score=0.869 total time=  41.7s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=500;, score=0.815 total time=  42.8s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=500;, score=0.777 total time=  42.3s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=500;, score=0.852 total time=  42.3s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=750;, score=0.892 total time= 1.0min
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=750;, score=0.868 total time= 1.0min
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=750;, score=0.817 total time= 1.1min
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=750;, score=0.771 total time= 1.1min
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=750;, score=0.851 total time= 1.1min
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.852 total time=   8.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.875 total time=   8.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.837 total time=   8.2s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.782 total time=   8.3s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.839 total time=   8.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.873 total time=  14.7s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.881 total time=  14.8s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.830 total time=  14.8s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.785 total time=  14.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=0.841 total time=  14.7s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.889 total time=  34.8s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.890 total time=  35.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.825 total time=  35.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.785 total time=  35.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=250;, score=0.846 total time=  35.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=500;, score=0.898 total time= 1.1min
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=500;, score=0.886 total time= 1.1min
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=500;, score=0.841 total time= 1.1min
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=500;, score=0.792 total time= 1.1min
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=500;, score=0.851 total time= 1.1min
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=750;, score=0.900 total time= 1.7min
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=750;, score=0.884 total time= 1.7min
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=750;, score=0.841 total time= 1.7min
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=750;, score=0.794 total time= 1.7min
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=750;, score=0.850 total time= 1.7min
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=50;, score=0.798 total time=   2.8s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=50;, score=0.839 total time=   2.8s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=50;, score=0.766 total time=   2.8s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=50;, score=0.743 total time=   2.8s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=50;, score=0.764 total time=   2.8s
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=100;, score=0.791 total time=   4.4s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=100;, score=0.837 total time=   4.4s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=100;, score=0.770 total time=   4.4s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=100;, score=0.736 total time=   4.4s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=100;, score=0.773 total time=   4.4s
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=250;, score=0.776 total time=   9.2s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=250;, score=0.831 total time=   9.1s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=250;, score=0.758 total time=   9.1s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=250;, score=0.731 total time=   9.1s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=250;, score=0.776 total time=   9.1s
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=500;, score=0.757 total time=  16.9s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=500;, score=0.820 total time=  16.9s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=500;, score=0.749 total time=  16.9s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=500;, score=0.729 total time=  16.9s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=500;, score=0.772 total time=  16.9s
# [CV 1/5] END learning_rate=0.2, max_depth=1, n_estimators=750;, score=0.748 total time=  24.7s
# [CV 2/5] END learning_rate=0.2, max_depth=1, n_estimators=750;, score=0.814 total time=  24.7s
# [CV 3/5] END learning_rate=0.2, max_depth=1, n_estimators=750;, score=0.745 total time=  24.6s
# [CV 4/5] END learning_rate=0.2, max_depth=1, n_estimators=750;, score=0.727 total time=  24.8s
# [CV 5/5] END learning_rate=0.2, max_depth=1, n_estimators=750;, score=0.768 total time=  24.7s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.856 total time=   5.2s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.868 total time=   5.3s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.824 total time=   5.3s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.761 total time=   5.3s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=50;, score=0.841 total time=   5.3s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.862 total time=   9.4s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.872 total time=   9.4s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.822 total time=   9.4s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.768 total time=   9.4s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=100;, score=0.846 total time=   9.4s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=250;, score=0.866 total time=  21.7s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=250;, score=0.874 total time=  21.8s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=250;, score=0.829 total time=  21.8s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=250;, score=0.766 total time=  21.8s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=250;, score=0.846 total time=  21.9s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.874 total time=  42.5s
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.886 total time=  42.4s
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.826 total time=  42.7s
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.759 total time=  42.5s
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.854 total time=  42.5s
# [CV 1/5] END learning_rate=0.2, max_depth=3, n_estimators=750;, score=0.880 total time= 1.1min
# [CV 2/5] END learning_rate=0.2, max_depth=3, n_estimators=750;, score=0.881 total time= 1.1min
# [CV 3/5] END learning_rate=0.2, max_depth=3, n_estimators=750;, score=0.823 total time= 1.1min
# [CV 4/5] END learning_rate=0.2, max_depth=3, n_estimators=750;, score=0.761 total time= 1.1min
# [CV 5/5] END learning_rate=0.2, max_depth=3, n_estimators=750;, score=0.855 total time= 1.1min
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.876 total time=   8.0s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.883 total time=   8.0s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.828 total time=   8.0s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.774 total time=   8.0s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=50;, score=0.875 total time=   8.0s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.896 total time=  14.8s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.889 total time=  14.9s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.819 total time=  15.0s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.776 total time=  15.0s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=100;, score=0.879 total time=  15.0s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=250;, score=0.897 total time=  35.3s
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=250;, score=0.890 total time=  35.5s
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=250;, score=0.831 total time=  35.6s
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=250;, score=0.787 total time=  35.5s
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=250;, score=0.884 total time=  35.6s
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=500;, score=0.903 total time= 1.2min
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=500;, score=0.890 total time= 1.2min
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=500;, score=0.827 total time= 1.2min
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=500;, score=0.794 total time= 1.2min
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=500;, score=0.884 total time= 1.2min
# [CV 1/5] END learning_rate=0.2, max_depth=5, n_estimators=750;, score=0.902 total time= 1.8min
# [CV 2/5] END learning_rate=0.2, max_depth=5, n_estimators=750;, score=0.890 total time= 1.7min
# [CV 3/5] END learning_rate=0.2, max_depth=5, n_estimators=750;, score=0.826 total time= 1.7min
# [CV 4/5] END learning_rate=0.2, max_depth=5, n_estimators=750;, score=0.792 total time= 1.7min
# [CV 5/5] END learning_rate=0.2, max_depth=5, n_estimators=750;, score=0.882 total time= 1.7min
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=0.798 total time=   2.8s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=0.839 total time=   2.9s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=0.769 total time=   2.8s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=0.734 total time=   2.8s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=0.768 total time=   2.8s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=0.788 total time=   4.5s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=0.836 total time=   4.5s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=0.769 total time=   4.5s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=0.731 total time=   4.4s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=0.780 total time=   4.4s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=250;, score=0.763 total time=   9.3s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=250;, score=0.822 total time=   9.3s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=250;, score=0.756 total time=   9.2s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=250;, score=0.726 total time=   9.2s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=250;, score=0.774 total time=   9.5s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=500;, score=0.747 total time=  17.3s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=500;, score=0.814 total time=  16.9s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=500;, score=0.746 total time=  16.5s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=500;, score=0.726 total time=  16.2s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=500;, score=0.768 total time=  15.9s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=750;, score=0.743 total time=  23.2s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=750;, score=0.808 total time=  23.0s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=750;, score=0.741 total time=  22.9s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=750;, score=0.728 total time=  23.0s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=750;, score=0.765 total time=  23.0s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.859 total time=   4.9s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.882 total time=   4.9s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.794 total time=   4.9s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.786 total time=   4.9s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=0.860 total time=   4.9s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.874 total time=   8.7s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.897 total time=   8.7s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.814 total time=   8.7s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.793 total time=   8.7s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=0.871 total time=   8.7s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=250;, score=0.887 total time=  20.0s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=250;, score=0.891 total time=  20.1s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=250;, score=0.824 total time=  20.0s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=250;, score=0.792 total time=  20.0s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=250;, score=0.883 total time=  20.0s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=500;, score=0.890 total time=  39.1s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=500;, score=0.891 total time=  39.0s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=500;, score=0.827 total time=  39.1s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=500;, score=0.794 total time=  39.1s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=500;, score=0.883 total time=  39.3s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=750;, score=0.892 total time=  54.8s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=750;, score=0.890 total time=  51.3s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=750;, score=0.827 total time=  52.0s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=750;, score=0.795 total time=  52.4s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=750;, score=0.882 total time=  52.8s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.886 total time=   6.9s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.873 total time=   6.9s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.844 total time=   6.9s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.782 total time=   6.9s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=0.857 total time=   6.9s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.893 total time=  12.6s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.880 total time=  12.6s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.846 total time=  12.6s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.772 total time=  12.6s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=0.870 total time=  12.6s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=250;, score=0.899 total time=  29.6s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=250;, score=0.884 total time=  29.6s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=250;, score=0.848 total time=  29.7s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=250;, score=0.778 total time=  29.7s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=250;, score=0.872 total time=  29.5s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=500;, score=0.897 total time=  57.2s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=500;, score=0.883 total time=  56.7s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=500;, score=0.849 total time=  56.9s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=500;, score=0.779 total time=  58.0s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=500;, score=0.871 total time=  57.5s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=750;, score=0.897 total time= 1.4min
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=750;, score=0.882 total time= 1.4min
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=750;, score=0.848 total time= 1.4min
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=750;, score=0.780 total time= 1.4min
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=750;, score=0.870 total time= 1.4min
# {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 500}

# %%
# fit optimized model and plot learning curves
xgb = XGBClassifier(scale_pos_weight=1/imbalance, learning_rate=0.2, n_estimators=500, max_depth=5,
                    n_jobs=cpus, use_label_encoder=False)
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)
eval_set = [(X_tr, y_tr), (X_val, y_val)]
xgb.fit(X_tr, y_tr, eval_metric='auc', eval_set=eval_set)
results = xgb.evals_result()
epochs = len(results['validation_0']['auc'])
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(range(0, epochs), results['validation_0']['auc'], label='Train')
ax.plot(range(0, epochs), results['validation_1']['auc'], label='Test')
ax.legend()
ax.set_ylabel('ROC-AUC')
ax.set_xlabel('# of XGB estimators')
ax.set_ylim(0.5, 1.01)
fig.savefig(results_dir+'/models/v22_multi_language_learning_curve.png', dpi=400)
# Out:
# [0]	validation_0-auc:0.90894	validation_1-auc:0.75502
# [1]	validation_0-auc:0.93474	validation_1-auc:0.73120
# [2]	validation_0-auc:0.95118	validation_1-auc:0.75912
# [3]	validation_0-auc:0.95917	validation_1-auc:0.74978
# [4]	validation_0-auc:0.96077	validation_1-auc:0.76022
# [5]	validation_0-auc:0.96709	validation_1-auc:0.74988
# [6]	validation_0-auc:0.97447	validation_1-auc:0.75753
# [7]	validation_0-auc:0.97929	validation_1-auc:0.75451
# [8]	validation_0-auc:0.98265	validation_1-auc:0.75569
# [9]	validation_0-auc:0.98462	validation_1-auc:0.74224
# [10]	validation_0-auc:0.98565	validation_1-auc:0.74474
# [11]	validation_0-auc:0.98810	validation_1-auc:0.75127
# [12]	validation_0-auc:0.98952	validation_1-auc:0.74273
# [13]	validation_0-auc:0.98989	validation_1-auc:0.73826
# [14]	validation_0-auc:0.99012	validation_1-auc:0.73635
# [15]	validation_0-auc:0.99067	validation_1-auc:0.74488
# [16]	validation_0-auc:0.99089	validation_1-auc:0.74326
# [17]	validation_0-auc:0.99178	validation_1-auc:0.74827
# [18]	validation_0-auc:0.99194	validation_1-auc:0.74803
# [19]	validation_0-auc:0.99212	validation_1-auc:0.74847
# [20]	validation_0-auc:0.99297	validation_1-auc:0.74696
# [21]	validation_0-auc:0.99324	validation_1-auc:0.74751
# [22]	validation_0-auc:0.99353	validation_1-auc:0.75019
# [23]	validation_0-auc:0.99370	validation_1-auc:0.74743
# [24]	validation_0-auc:0.99385	validation_1-auc:0.74538
# [25]	validation_0-auc:0.99404	validation_1-auc:0.75008
# [26]	validation_0-auc:0.99399	validation_1-auc:0.74450
# [27]	validation_0-auc:0.99404	validation_1-auc:0.74396
# [28]	validation_0-auc:0.99414	validation_1-auc:0.74463
# [29]	validation_0-auc:0.99421	validation_1-auc:0.74207
# [30]	validation_0-auc:0.99466	validation_1-auc:0.74769
# [31]	validation_0-auc:0.99514	validation_1-auc:0.75136
# [32]	validation_0-auc:0.99567	validation_1-auc:0.74807
# [33]	validation_0-auc:0.99610	validation_1-auc:0.75028
# [34]	validation_0-auc:0.99622	validation_1-auc:0.74990
# [35]	validation_0-auc:0.99649	validation_1-auc:0.74633
# [36]	validation_0-auc:0.99659	validation_1-auc:0.74174
# [37]	validation_0-auc:0.99661	validation_1-auc:0.74322
# [38]	validation_0-auc:0.99691	validation_1-auc:0.74348
# [39]	validation_0-auc:0.99694	validation_1-auc:0.73918
# [40]	validation_0-auc:0.99705	validation_1-auc:0.74109
# [41]	validation_0-auc:0.99719	validation_1-auc:0.74094
# [42]	validation_0-auc:0.99725	validation_1-auc:0.74592
# [43]	validation_0-auc:0.99725	validation_1-auc:0.74148
# [44]	validation_0-auc:0.99733	validation_1-auc:0.73911
# [45]	validation_0-auc:0.99738	validation_1-auc:0.74045
# [46]	validation_0-auc:0.99739	validation_1-auc:0.73894
# [47]	validation_0-auc:0.99753	validation_1-auc:0.73954
# [48]	validation_0-auc:0.99755	validation_1-auc:0.74064
# [49]	validation_0-auc:0.99771	validation_1-auc:0.73975
# [50]	validation_0-auc:0.99777	validation_1-auc:0.74007
# [51]	validation_0-auc:0.99784	validation_1-auc:0.74151
# [52]	validation_0-auc:0.99801	validation_1-auc:0.74404
# [53]	validation_0-auc:0.99819	validation_1-auc:0.74492
# [54]	validation_0-auc:0.99832	validation_1-auc:0.74617
# [55]	validation_0-auc:0.99843	validation_1-auc:0.74630
# [56]	validation_0-auc:0.99851	validation_1-auc:0.74791
# [57]	validation_0-auc:0.99862	validation_1-auc:0.74986
# [58]	validation_0-auc:0.99876	validation_1-auc:0.74923
# [59]	validation_0-auc:0.99882	validation_1-auc:0.74720
# [60]	validation_0-auc:0.99892	validation_1-auc:0.74837
# [61]	validation_0-auc:0.99895	validation_1-auc:0.75128
# [62]	validation_0-auc:0.99902	validation_1-auc:0.75162
# [63]	validation_0-auc:0.99906	validation_1-auc:0.75023
# [64]	validation_0-auc:0.99912	validation_1-auc:0.75129
# [65]	validation_0-auc:0.99913	validation_1-auc:0.75026
# [66]	validation_0-auc:0.99916	validation_1-auc:0.75102
# [67]	validation_0-auc:0.99917	validation_1-auc:0.75098
# [68]	validation_0-auc:0.99919	validation_1-auc:0.75244
# [69]	validation_0-auc:0.99924	validation_1-auc:0.75226
# [70]	validation_0-auc:0.99924	validation_1-auc:0.75302
# [71]	validation_0-auc:0.99926	validation_1-auc:0.75443
# [72]	validation_0-auc:0.99925	validation_1-auc:0.75330
# [73]	validation_0-auc:0.99927	validation_1-auc:0.75258
# [74]	validation_0-auc:0.99931	validation_1-auc:0.75342
# [75]	validation_0-auc:0.99932	validation_1-auc:0.75393
# [76]	validation_0-auc:0.99932	validation_1-auc:0.75306
# [77]	validation_0-auc:0.99935	validation_1-auc:0.75479
# [78]	validation_0-auc:0.99938	validation_1-auc:0.75657
# [79]	validation_0-auc:0.99938	validation_1-auc:0.75836
# [80]	validation_0-auc:0.99939	validation_1-auc:0.75693
# [81]	validation_0-auc:0.99939	validation_1-auc:0.75444
# [82]	validation_0-auc:0.99940	validation_1-auc:0.75586
# [83]	validation_0-auc:0.99942	validation_1-auc:0.75702
# [84]	validation_0-auc:0.99944	validation_1-auc:0.75614
# [85]	validation_0-auc:0.99944	validation_1-auc:0.75648
# [86]	validation_0-auc:0.99945	validation_1-auc:0.75688
# [87]	validation_0-auc:0.99946	validation_1-auc:0.75646
# [88]	validation_0-auc:0.99946	validation_1-auc:0.75449
# [89]	validation_0-auc:0.99947	validation_1-auc:0.75270
# [90]	validation_0-auc:0.99948	validation_1-auc:0.75208
# [91]	validation_0-auc:0.99949	validation_1-auc:0.75405
# [92]	validation_0-auc:0.99950	validation_1-auc:0.75504
# [93]	validation_0-auc:0.99951	validation_1-auc:0.75672
# [94]	validation_0-auc:0.99952	validation_1-auc:0.75704
# [95]	validation_0-auc:0.99953	validation_1-auc:0.75756
# [96]	validation_0-auc:0.99953	validation_1-auc:0.75732
# [97]	validation_0-auc:0.99955	validation_1-auc:0.75824
# [98]	validation_0-auc:0.99956	validation_1-auc:0.75779
# [99]	validation_0-auc:0.99956	validation_1-auc:0.75823
# [100]	validation_0-auc:0.99957	validation_1-auc:0.76067
# [101]	validation_0-auc:0.99957	validation_1-auc:0.76011
# [102]	validation_0-auc:0.99958	validation_1-auc:0.76040
# [103]	validation_0-auc:0.99958	validation_1-auc:0.76106
# [104]	validation_0-auc:0.99958	validation_1-auc:0.76071
# [105]	validation_0-auc:0.99958	validation_1-auc:0.76015
# [106]	validation_0-auc:0.99959	validation_1-auc:0.76056
# [107]	validation_0-auc:0.99959	validation_1-auc:0.76192
# [108]	validation_0-auc:0.99960	validation_1-auc:0.76130
# [109]	validation_0-auc:0.99960	validation_1-auc:0.76240
# [110]	validation_0-auc:0.99961	validation_1-auc:0.76170
# [111]	validation_0-auc:0.99961	validation_1-auc:0.76217
# [112]	validation_0-auc:0.99962	validation_1-auc:0.76083
# [113]	validation_0-auc:0.99962	validation_1-auc:0.76003
# [114]	validation_0-auc:0.99962	validation_1-auc:0.75818
# [115]	validation_0-auc:0.99962	validation_1-auc:0.75763
# [116]	validation_0-auc:0.99964	validation_1-auc:0.75648
# [117]	validation_0-auc:0.99964	validation_1-auc:0.75496
# [118]	validation_0-auc:0.99964	validation_1-auc:0.75400
# [119]	validation_0-auc:0.99964	validation_1-auc:0.75317
# [120]	validation_0-auc:0.99964	validation_1-auc:0.75456
# [121]	validation_0-auc:0.99964	validation_1-auc:0.75613
# [122]	validation_0-auc:0.99965	validation_1-auc:0.75677
# [123]	validation_0-auc:0.99966	validation_1-auc:0.75685
# [124]	validation_0-auc:0.99966	validation_1-auc:0.75646
# [125]	validation_0-auc:0.99967	validation_1-auc:0.75610
# [126]	validation_0-auc:0.99967	validation_1-auc:0.75467
# [127]	validation_0-auc:0.99967	validation_1-auc:0.75441
# [128]	validation_0-auc:0.99968	validation_1-auc:0.75444
# [129]	validation_0-auc:0.99968	validation_1-auc:0.75473
# [130]	validation_0-auc:0.99968	validation_1-auc:0.75524
# [131]	validation_0-auc:0.99968	validation_1-auc:0.75542
# [132]	validation_0-auc:0.99969	validation_1-auc:0.75546
# [133]	validation_0-auc:0.99969	validation_1-auc:0.75548
# [134]	validation_0-auc:0.99969	validation_1-auc:0.75611
# [135]	validation_0-auc:0.99970	validation_1-auc:0.75676
# [136]	validation_0-auc:0.99970	validation_1-auc:0.75563
# [137]	validation_0-auc:0.99970	validation_1-auc:0.75591
# [138]	validation_0-auc:0.99970	validation_1-auc:0.75447
# [139]	validation_0-auc:0.99970	validation_1-auc:0.75512
# [140]	validation_0-auc:0.99970	validation_1-auc:0.75441
# [141]	validation_0-auc:0.99971	validation_1-auc:0.75610
# [142]	validation_0-auc:0.99971	validation_1-auc:0.75504
# [143]	validation_0-auc:0.99971	validation_1-auc:0.75558
# [144]	validation_0-auc:0.99971	validation_1-auc:0.75648
# [145]	validation_0-auc:0.99971	validation_1-auc:0.75633
# [146]	validation_0-auc:0.99972	validation_1-auc:0.75676
# [147]	validation_0-auc:0.99972	validation_1-auc:0.75640
# [148]	validation_0-auc:0.99972	validation_1-auc:0.75492
# [149]	validation_0-auc:0.99972	validation_1-auc:0.75535
# [150]	validation_0-auc:0.99972	validation_1-auc:0.75492
# [151]	validation_0-auc:0.99972	validation_1-auc:0.75444
# [152]	validation_0-auc:0.99972	validation_1-auc:0.75432
# [153]	validation_0-auc:0.99972	validation_1-auc:0.75417
# [154]	validation_0-auc:0.99972	validation_1-auc:0.75311
# [155]	validation_0-auc:0.99972	validation_1-auc:0.75343
# [156]	validation_0-auc:0.99972	validation_1-auc:0.75287
# [157]	validation_0-auc:0.99972	validation_1-auc:0.75347
# [158]	validation_0-auc:0.99972	validation_1-auc:0.75349
# [159]	validation_0-auc:0.99972	validation_1-auc:0.75362
# [160]	validation_0-auc:0.99972	validation_1-auc:0.75283
# [161]	validation_0-auc:0.99972	validation_1-auc:0.75318
# [162]	validation_0-auc:0.99972	validation_1-auc:0.75357
# [163]	validation_0-auc:0.99972	validation_1-auc:0.75241
# [164]	validation_0-auc:0.99972	validation_1-auc:0.75226
# [165]	validation_0-auc:0.99972	validation_1-auc:0.75357
# [166]	validation_0-auc:0.99972	validation_1-auc:0.75367
# [167]	validation_0-auc:0.99972	validation_1-auc:0.75335
# [168]	validation_0-auc:0.99972	validation_1-auc:0.75360
# [169]	validation_0-auc:0.99972	validation_1-auc:0.75448
# [170]	validation_0-auc:0.99972	validation_1-auc:0.75475
# [171]	validation_0-auc:0.99972	validation_1-auc:0.75417
# [172]	validation_0-auc:0.99972	validation_1-auc:0.75437
# [173]	validation_0-auc:0.99972	validation_1-auc:0.75429
# [174]	validation_0-auc:0.99972	validation_1-auc:0.75443
# [175]	validation_0-auc:0.99972	validation_1-auc:0.75457
# [176]	validation_0-auc:0.99972	validation_1-auc:0.75386
# [177]	validation_0-auc:0.99972	validation_1-auc:0.75409
# [178]	validation_0-auc:0.99972	validation_1-auc:0.75409
# [179]	validation_0-auc:0.99972	validation_1-auc:0.75428
# [180]	validation_0-auc:0.99972	validation_1-auc:0.75417
# [181]	validation_0-auc:0.99972	validation_1-auc:0.75388
# [182]	validation_0-auc:0.99972	validation_1-auc:0.75361
# [183]	validation_0-auc:0.99972	validation_1-auc:0.75366
# [184]	validation_0-auc:0.99972	validation_1-auc:0.75401
# [185]	validation_0-auc:0.99972	validation_1-auc:0.75523
# [186]	validation_0-auc:0.99972	validation_1-auc:0.75534
# [187]	validation_0-auc:0.99972	validation_1-auc:0.75526
# [188]	validation_0-auc:0.99972	validation_1-auc:0.75469
# [189]	validation_0-auc:0.99972	validation_1-auc:0.75501
# [190]	validation_0-auc:0.99972	validation_1-auc:0.75539
# [191]	validation_0-auc:0.99972	validation_1-auc:0.75509
# [192]	validation_0-auc:0.99972	validation_1-auc:0.75516
# [193]	validation_0-auc:0.99972	validation_1-auc:0.75494
# [194]	validation_0-auc:0.99972	validation_1-auc:0.75530
# [195]	validation_0-auc:0.99972	validation_1-auc:0.75563
# [196]	validation_0-auc:0.99972	validation_1-auc:0.75642
# [197]	validation_0-auc:0.99972	validation_1-auc:0.75520
# [198]	validation_0-auc:0.99972	validation_1-auc:0.75489
# [199]	validation_0-auc:0.99972	validation_1-auc:0.75481
# [200]	validation_0-auc:0.99972	validation_1-auc:0.75453
# [201]	validation_0-auc:0.99972	validation_1-auc:0.75414
# [202]	validation_0-auc:0.99972	validation_1-auc:0.75398
# [203]	validation_0-auc:0.99972	validation_1-auc:0.75405
# [204]	validation_0-auc:0.99972	validation_1-auc:0.75372
# [205]	validation_0-auc:0.99972	validation_1-auc:0.75382
# [206]	validation_0-auc:0.99972	validation_1-auc:0.75424
# [207]	validation_0-auc:0.99972	validation_1-auc:0.75402
# [208]	validation_0-auc:0.99972	validation_1-auc:0.75401
# [209]	validation_0-auc:0.99972	validation_1-auc:0.75339
# [210]	validation_0-auc:0.99972	validation_1-auc:0.75315
# [211]	validation_0-auc:0.99972	validation_1-auc:0.75322
# [212]	validation_0-auc:0.99972	validation_1-auc:0.75393
# [213]	validation_0-auc:0.99972	validation_1-auc:0.75400
# [214]	validation_0-auc:0.99972	validation_1-auc:0.75357
# [215]	validation_0-auc:0.99972	validation_1-auc:0.75381
# [216]	validation_0-auc:0.99972	validation_1-auc:0.75303
# [217]	validation_0-auc:0.99972	validation_1-auc:0.75270
# [218]	validation_0-auc:0.99972	validation_1-auc:0.75326
# [219]	validation_0-auc:0.99972	validation_1-auc:0.75301
# [220]	validation_0-auc:0.99972	validation_1-auc:0.75240
# [221]	validation_0-auc:0.99972	validation_1-auc:0.75215
# [222]	validation_0-auc:0.99972	validation_1-auc:0.75250
# [223]	validation_0-auc:0.99972	validation_1-auc:0.75275
# [224]	validation_0-auc:0.99972	validation_1-auc:0.75264
# [225]	validation_0-auc:0.99972	validation_1-auc:0.75236
# [226]	validation_0-auc:0.99972	validation_1-auc:0.75314
# [227]	validation_0-auc:0.99972	validation_1-auc:0.75274
# [228]	validation_0-auc:0.99972	validation_1-auc:0.75275
# [229]	validation_0-auc:0.99972	validation_1-auc:0.75291
# [230]	validation_0-auc:0.99972	validation_1-auc:0.75309
# [231]	validation_0-auc:0.99972	validation_1-auc:0.75325
# [232]	validation_0-auc:0.99972	validation_1-auc:0.75291
# [233]	validation_0-auc:0.99972	validation_1-auc:0.75347
# [234]	validation_0-auc:0.99972	validation_1-auc:0.75366
# [235]	validation_0-auc:0.99972	validation_1-auc:0.75288
# [236]	validation_0-auc:0.99972	validation_1-auc:0.75259
# [237]	validation_0-auc:0.99972	validation_1-auc:0.75250
# [238]	validation_0-auc:0.99972	validation_1-auc:0.75208
# [239]	validation_0-auc:0.99972	validation_1-auc:0.75233
# [240]	validation_0-auc:0.99972	validation_1-auc:0.75258
# [241]	validation_0-auc:0.99972	validation_1-auc:0.75230
# [242]	validation_0-auc:0.99972	validation_1-auc:0.75274
# [243]	validation_0-auc:0.99972	validation_1-auc:0.75287
# [244]	validation_0-auc:0.99972	validation_1-auc:0.75326
# [245]	validation_0-auc:0.99972	validation_1-auc:0.75327
# [246]	validation_0-auc:0.99972	validation_1-auc:0.75339
# [247]	validation_0-auc:0.99972	validation_1-auc:0.75337
# [248]	validation_0-auc:0.99972	validation_1-auc:0.75276
# [249]	validation_0-auc:0.99972	validation_1-auc:0.75299
# [250]	validation_0-auc:0.99972	validation_1-auc:0.75306
# [251]	validation_0-auc:0.99972	validation_1-auc:0.75287
# [252]	validation_0-auc:0.99972	validation_1-auc:0.75275
# [253]	validation_0-auc:0.99972	validation_1-auc:0.75235
# [254]	validation_0-auc:0.99972	validation_1-auc:0.75227
# [255]	validation_0-auc:0.99972	validation_1-auc:0.75276
# [256]	validation_0-auc:0.99972	validation_1-auc:0.75268
# [257]	validation_0-auc:0.99972	validation_1-auc:0.75267
# [258]	validation_0-auc:0.99972	validation_1-auc:0.75313
# [259]	validation_0-auc:0.99972	validation_1-auc:0.75346
# [260]	validation_0-auc:0.99972	validation_1-auc:0.75275
# [261]	validation_0-auc:0.99972	validation_1-auc:0.75260
# [262]	validation_0-auc:0.99972	validation_1-auc:0.75247
# [263]	validation_0-auc:0.99972	validation_1-auc:0.75256
# [264]	validation_0-auc:0.99972	validation_1-auc:0.75248
# [265]	validation_0-auc:0.99972	validation_1-auc:0.75263
# [266]	validation_0-auc:0.99972	validation_1-auc:0.75231
# [267]	validation_0-auc:0.99972	validation_1-auc:0.75193
# [268]	validation_0-auc:0.99972	validation_1-auc:0.75200
# [269]	validation_0-auc:0.99972	validation_1-auc:0.75177
# [270]	validation_0-auc:0.99972	validation_1-auc:0.75176
# [271]	validation_0-auc:0.99972	validation_1-auc:0.75148
# [272]	validation_0-auc:0.99972	validation_1-auc:0.75149
# [273]	validation_0-auc:0.99972	validation_1-auc:0.75129
# [274]	validation_0-auc:0.99972	validation_1-auc:0.75128
# [275]	validation_0-auc:0.99972	validation_1-auc:0.75121
# [276]	validation_0-auc:0.99972	validation_1-auc:0.75105
# [277]	validation_0-auc:0.99972	validation_1-auc:0.75098
# [278]	validation_0-auc:0.99972	validation_1-auc:0.75114
# [279]	validation_0-auc:0.99972	validation_1-auc:0.75145
# [280]	validation_0-auc:0.99972	validation_1-auc:0.75137
# [281]	validation_0-auc:0.99972	validation_1-auc:0.75177
# [282]	validation_0-auc:0.99972	validation_1-auc:0.75164
# [283]	validation_0-auc:0.99972	validation_1-auc:0.75148
# [284]	validation_0-auc:0.99972	validation_1-auc:0.75149
# [285]	validation_0-auc:0.99972	validation_1-auc:0.75148
# [286]	validation_0-auc:0.99972	validation_1-auc:0.75172
# [287]	validation_0-auc:0.99972	validation_1-auc:0.75116
# [288]	validation_0-auc:0.99972	validation_1-auc:0.75109
# [289]	validation_0-auc:0.99972	validation_1-auc:0.75087
# [290]	validation_0-auc:0.99972	validation_1-auc:0.75150
# [291]	validation_0-auc:0.99972	validation_1-auc:0.75126
# [292]	validation_0-auc:0.99972	validation_1-auc:0.75126
# [293]	validation_0-auc:0.99972	validation_1-auc:0.75121
# [294]	validation_0-auc:0.99972	validation_1-auc:0.75106
# [295]	validation_0-auc:0.99972	validation_1-auc:0.75112
# [296]	validation_0-auc:0.99972	validation_1-auc:0.75108
# [297]	validation_0-auc:0.99972	validation_1-auc:0.75129
# [298]	validation_0-auc:0.99972	validation_1-auc:0.75146
# [299]	validation_0-auc:0.99972	validation_1-auc:0.75165
# [300]	validation_0-auc:0.99972	validation_1-auc:0.75148
# [301]	validation_0-auc:0.99972	validation_1-auc:0.75154
# [302]	validation_0-auc:0.99972	validation_1-auc:0.75116
# [303]	validation_0-auc:0.99972	validation_1-auc:0.75137
# [304]	validation_0-auc:0.99972	validation_1-auc:0.75094
# [305]	validation_0-auc:0.99972	validation_1-auc:0.75126
# [306]	validation_0-auc:0.99972	validation_1-auc:0.75112
# [307]	validation_0-auc:0.99972	validation_1-auc:0.75089
# [308]	validation_0-auc:0.99972	validation_1-auc:0.75102
# [309]	validation_0-auc:0.99972	validation_1-auc:0.75154
# [310]	validation_0-auc:0.99972	validation_1-auc:0.75145
# [311]	validation_0-auc:0.99972	validation_1-auc:0.75154
# [312]	validation_0-auc:0.99972	validation_1-auc:0.75121
# [313]	validation_0-auc:0.99972	validation_1-auc:0.75142
# [314]	validation_0-auc:0.99972	validation_1-auc:0.75101
# [315]	validation_0-auc:0.99972	validation_1-auc:0.75138
# [316]	validation_0-auc:0.99972	validation_1-auc:0.75174
# [317]	validation_0-auc:0.99972	validation_1-auc:0.75133
# [318]	validation_0-auc:0.99972	validation_1-auc:0.75142
# [319]	validation_0-auc:0.99972	validation_1-auc:0.75130
# [320]	validation_0-auc:0.99972	validation_1-auc:0.75169
# [321]	validation_0-auc:0.99972	validation_1-auc:0.75153
# [322]	validation_0-auc:0.99972	validation_1-auc:0.75128
# [323]	validation_0-auc:0.99972	validation_1-auc:0.75142
# [324]	validation_0-auc:0.99972	validation_1-auc:0.75097
# [325]	validation_0-auc:0.99972	validation_1-auc:0.75117
# [326]	validation_0-auc:0.99972	validation_1-auc:0.75096
# [327]	validation_0-auc:0.99972	validation_1-auc:0.75053
# [328]	validation_0-auc:0.99972	validation_1-auc:0.75061
# [329]	validation_0-auc:0.99972	validation_1-auc:0.75063
# [330]	validation_0-auc:0.99972	validation_1-auc:0.75059
# [331]	validation_0-auc:0.99972	validation_1-auc:0.75063
# [332]	validation_0-auc:0.99972	validation_1-auc:0.75104
# [333]	validation_0-auc:0.99972	validation_1-auc:0.75081
# [334]	validation_0-auc:0.99972	validation_1-auc:0.75045
# [335]	validation_0-auc:0.99972	validation_1-auc:0.75082
# [336]	validation_0-auc:0.99972	validation_1-auc:0.75116
# [337]	validation_0-auc:0.99972	validation_1-auc:0.75153
# [338]	validation_0-auc:0.99972	validation_1-auc:0.75154
# [339]	validation_0-auc:0.99972	validation_1-auc:0.75121
# [340]	validation_0-auc:0.99972	validation_1-auc:0.75110
# [341]	validation_0-auc:0.99972	validation_1-auc:0.75086
# [342]	validation_0-auc:0.99972	validation_1-auc:0.75082
# [343]	validation_0-auc:0.99972	validation_1-auc:0.75030
# [344]	validation_0-auc:0.99972	validation_1-auc:0.75043
# [345]	validation_0-auc:0.99972	validation_1-auc:0.75047
# [346]	validation_0-auc:0.99972	validation_1-auc:0.75039
# [347]	validation_0-auc:0.99972	validation_1-auc:0.75075
# [348]	validation_0-auc:0.99972	validation_1-auc:0.75081
# [349]	validation_0-auc:0.99972	validation_1-auc:0.75047
# [350]	validation_0-auc:0.99972	validation_1-auc:0.75065
# [351]	validation_0-auc:0.99972	validation_1-auc:0.75093
# [352]	validation_0-auc:0.99972	validation_1-auc:0.75101
# [353]	validation_0-auc:0.99972	validation_1-auc:0.75078
# [354]	validation_0-auc:0.99972	validation_1-auc:0.75099
# [355]	validation_0-auc:0.99972	validation_1-auc:0.75070
# [356]	validation_0-auc:0.99972	validation_1-auc:0.75053
# [357]	validation_0-auc:0.99972	validation_1-auc:0.75078
# [358]	validation_0-auc:0.99972	validation_1-auc:0.75075
# [359]	validation_0-auc:0.99972	validation_1-auc:0.75089
# [360]	validation_0-auc:0.99972	validation_1-auc:0.75058
# [361]	validation_0-auc:0.99972	validation_1-auc:0.75090
# [362]	validation_0-auc:0.99972	validation_1-auc:0.75096
# [363]	validation_0-auc:0.99972	validation_1-auc:0.75122
# [364]	validation_0-auc:0.99972	validation_1-auc:0.75110
# [365]	validation_0-auc:0.99972	validation_1-auc:0.75091
# [366]	validation_0-auc:0.99972	validation_1-auc:0.75077
# [367]	validation_0-auc:0.99972	validation_1-auc:0.75067
# [368]	validation_0-auc:0.99972	validation_1-auc:0.75051
# [369]	validation_0-auc:0.99972	validation_1-auc:0.75035
# [370]	validation_0-auc:0.99972	validation_1-auc:0.75022
# [371]	validation_0-auc:0.99972	validation_1-auc:0.75031
# [372]	validation_0-auc:0.99972	validation_1-auc:0.75039
# [373]	validation_0-auc:0.99972	validation_1-auc:0.75012
# [374]	validation_0-auc:0.99972	validation_1-auc:0.75007
# [375]	validation_0-auc:0.99972	validation_1-auc:0.75026
# [376]	validation_0-auc:0.99972	validation_1-auc:0.75023
# [377]	validation_0-auc:0.99972	validation_1-auc:0.75026
# [378]	validation_0-auc:0.99972	validation_1-auc:0.75025
# [379]	validation_0-auc:0.99972	validation_1-auc:0.75018
# [380]	validation_0-auc:0.99972	validation_1-auc:0.75003
# [381]	validation_0-auc:0.99972	validation_1-auc:0.74975
# [382]	validation_0-auc:0.99972	validation_1-auc:0.74967
# [383]	validation_0-auc:0.99972	validation_1-auc:0.74952
# [384]	validation_0-auc:0.99972	validation_1-auc:0.74920
# [385]	validation_0-auc:0.99972	validation_1-auc:0.74936
# [386]	validation_0-auc:0.99972	validation_1-auc:0.74965
# [387]	validation_0-auc:0.99972	validation_1-auc:0.74979
# [388]	validation_0-auc:0.99972	validation_1-auc:0.74986
# [389]	validation_0-auc:0.99972	validation_1-auc:0.74978
# [390]	validation_0-auc:0.99972	validation_1-auc:0.74962
# [391]	validation_0-auc:0.99972	validation_1-auc:0.74967
# [392]	validation_0-auc:0.99972	validation_1-auc:0.74952
# [393]	validation_0-auc:0.99972	validation_1-auc:0.74931
# [394]	validation_0-auc:0.99972	validation_1-auc:0.74935
# [395]	validation_0-auc:0.99972	validation_1-auc:0.74924
# [396]	validation_0-auc:0.99972	validation_1-auc:0.74891
# [397]	validation_0-auc:0.99972	validation_1-auc:0.74873
# [398]	validation_0-auc:0.99972	validation_1-auc:0.74886
# [399]	validation_0-auc:0.99972	validation_1-auc:0.74892
# [400]	validation_0-auc:0.99972	validation_1-auc:0.74913
# [401]	validation_0-auc:0.99972	validation_1-auc:0.74885
# [402]	validation_0-auc:0.99972	validation_1-auc:0.74903
# [403]	validation_0-auc:0.99972	validation_1-auc:0.74892
# [404]	validation_0-auc:0.99972	validation_1-auc:0.74901
# [405]	validation_0-auc:0.99972	validation_1-auc:0.74892
# [406]	validation_0-auc:0.99972	validation_1-auc:0.74905
# [407]	validation_0-auc:0.99972	validation_1-auc:0.74917
# [408]	validation_0-auc:0.99972	validation_1-auc:0.74905
# [409]	validation_0-auc:0.99972	validation_1-auc:0.74920
# [410]	validation_0-auc:0.99972	validation_1-auc:0.74920
# [411]	validation_0-auc:0.99972	validation_1-auc:0.74925
# [412]	validation_0-auc:0.99972	validation_1-auc:0.74944
# [413]	validation_0-auc:0.99972	validation_1-auc:0.74960
# [414]	validation_0-auc:0.99972	validation_1-auc:0.74975
# [415]	validation_0-auc:0.99972	validation_1-auc:0.74974
# [416]	validation_0-auc:0.99972	validation_1-auc:0.74983
# [417]	validation_0-auc:0.99972	validation_1-auc:0.74978
# [418]	validation_0-auc:0.99972	validation_1-auc:0.74964
# [419]	validation_0-auc:0.99972	validation_1-auc:0.74956
# [420]	validation_0-auc:0.99972	validation_1-auc:0.74952
# [421]	validation_0-auc:0.99972	validation_1-auc:0.74978
# [422]	validation_0-auc:0.99972	validation_1-auc:0.74971
# [423]	validation_0-auc:0.99972	validation_1-auc:0.74959
# [424]	validation_0-auc:0.99972	validation_1-auc:0.74962
# [425]	validation_0-auc:0.99972	validation_1-auc:0.74940
# [426]	validation_0-auc:0.99972	validation_1-auc:0.74929
# [427]	validation_0-auc:0.99972	validation_1-auc:0.74941
# [428]	validation_0-auc:0.99972	validation_1-auc:0.74979
# [429]	validation_0-auc:0.99972	validation_1-auc:0.74962
# [430]	validation_0-auc:0.99972	validation_1-auc:0.74980
# [431]	validation_0-auc:0.99972	validation_1-auc:0.74994
# [432]	validation_0-auc:0.99972	validation_1-auc:0.74998
# [433]	validation_0-auc:0.99972	validation_1-auc:0.74987
# [434]	validation_0-auc:0.99972	validation_1-auc:0.75019
# [435]	validation_0-auc:0.99972	validation_1-auc:0.75003
# [436]	validation_0-auc:0.99972	validation_1-auc:0.75025
# [437]	validation_0-auc:0.99972	validation_1-auc:0.75000
# [438]	validation_0-auc:0.99972	validation_1-auc:0.74995
# [439]	validation_0-auc:0.99972	validation_1-auc:0.75004
# [440]	validation_0-auc:0.99972	validation_1-auc:0.75014
# [441]	validation_0-auc:0.99972	validation_1-auc:0.75019
# [442]	validation_0-auc:0.99972	validation_1-auc:0.75036
# [443]	validation_0-auc:0.99972	validation_1-auc:0.75035
# [444]	validation_0-auc:0.99972	validation_1-auc:0.75059
# [445]	validation_0-auc:0.99972	validation_1-auc:0.75062
# [446]	validation_0-auc:0.99972	validation_1-auc:0.75069
# [447]	validation_0-auc:0.99972	validation_1-auc:0.75065
# [448]	validation_0-auc:0.99972	validation_1-auc:0.75059
# [449]	validation_0-auc:0.99972	validation_1-auc:0.75047
# [450]	validation_0-auc:0.99972	validation_1-auc:0.75036
# [451]	validation_0-auc:0.99972	validation_1-auc:0.75043
# [452]	validation_0-auc:0.99972	validation_1-auc:0.75023
# [453]	validation_0-auc:0.99972	validation_1-auc:0.75020
# [454]	validation_0-auc:0.99972	validation_1-auc:0.75036
# [455]	validation_0-auc:0.99972	validation_1-auc:0.75034
# [456]	validation_0-auc:0.99972	validation_1-auc:0.75054
# [457]	validation_0-auc:0.99972	validation_1-auc:0.75071
# [458]	validation_0-auc:0.99972	validation_1-auc:0.75069
# [459]	validation_0-auc:0.99972	validation_1-auc:0.75085
# [460]	validation_0-auc:0.99972	validation_1-auc:0.75067
# [461]	validation_0-auc:0.99972	validation_1-auc:0.75054
# [462]	validation_0-auc:0.99972	validation_1-auc:0.75065
# [463]	validation_0-auc:0.99972	validation_1-auc:0.75040
# [464]	validation_0-auc:0.99972	validation_1-auc:0.75065
# [465]	validation_0-auc:0.99972	validation_1-auc:0.75077
# [466]	validation_0-auc:0.99972	validation_1-auc:0.75065
# [467]	validation_0-auc:0.99972	validation_1-auc:0.75071
# [468]	validation_0-auc:0.99972	validation_1-auc:0.75067
# [469]	validation_0-auc:0.99972	validation_1-auc:0.75054
# [470]	validation_0-auc:0.99972	validation_1-auc:0.75069
# [471]	validation_0-auc:0.99972	validation_1-auc:0.75073
# [472]	validation_0-auc:0.99972	validation_1-auc:0.75078
# [473]	validation_0-auc:0.99972	validation_1-auc:0.75070
# [474]	validation_0-auc:0.99972	validation_1-auc:0.75050
# [475]	validation_0-auc:0.99972	validation_1-auc:0.75078
# [476]	validation_0-auc:0.99972	validation_1-auc:0.75075
# [477]	validation_0-auc:0.99972	validation_1-auc:0.75066
# [478]	validation_0-auc:0.99972	validation_1-auc:0.75062
# [479]	validation_0-auc:0.99972	validation_1-auc:0.75085
# [480]	validation_0-auc:0.99972	validation_1-auc:0.75081
# [481]	validation_0-auc:0.99972	validation_1-auc:0.75067
# [482]	validation_0-auc:0.99972	validation_1-auc:0.75062
# [483]	validation_0-auc:0.99972	validation_1-auc:0.75055
# [484]	validation_0-auc:0.99972	validation_1-auc:0.75025
# [485]	validation_0-auc:0.99972	validation_1-auc:0.75028
# [486]	validation_0-auc:0.99972	validation_1-auc:0.75057
# [487]	validation_0-auc:0.99972	validation_1-auc:0.75087
# [488]	validation_0-auc:0.99972	validation_1-auc:0.75091
# [489]	validation_0-auc:0.99972	validation_1-auc:0.75057
# [490]	validation_0-auc:0.99972	validation_1-auc:0.75050
# [491]	validation_0-auc:0.99972	validation_1-auc:0.75075
# [492]	validation_0-auc:0.99972	validation_1-auc:0.75063
# [493]	validation_0-auc:0.99972	validation_1-auc:0.75065
# [494]	validation_0-auc:0.99972	validation_1-auc:0.75069
# [495]	validation_0-auc:0.99972	validation_1-auc:0.75053
# [496]	validation_0-auc:0.99972	validation_1-auc:0.75070
# [497]	validation_0-auc:0.99972	validation_1-auc:0.75078
# [498]	validation_0-auc:0.99972	validation_1-auc:0.75053
# [499]	validation_0-auc:0.99972	validation_1-auc:0.75061

# %%
# test set evaluation
xgb = XGBClassifier(scale_pos_weight=1/imbalance, learning_rate=0.2, n_estimators=500, max_depth=5,
                    n_jobs=cpus, use_label_encoder=False)
xgb.fit(X_train, y_train)
score_xgb = xgb.predict_proba(X_test)[:,1]
print('AUC:', roc_auc_score(y_test, score_xgb))
# Out:
# [11:17:37] WARNING: /private/var/folders/p1/fvz7cyr12yl0lf647b14byy80000gn/T/pip-install-w5n3w6k9/xgboost_a8a36401f804426fb00f941f2eae565c/build/temp.macosx-11.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# AUC: 0.9223658933693994

# %%
results = pd.DataFrame({'labels': y_test, 'scores': score_xgb})
results.to_csv(results_dir+'/v2.2/language_xgb_scores.csv', index=False)

# %% [markdown]
# The fact that we're seeing a higher AUC on the test set then before with the learning curve to me indicates that sufficient data is crucial! In the learning curve, we splitted X_train up into train an validation, and result is lower AUC... so enough data seems crucial!

# %% [markdown]
# #### Randomized labels

# %%
random.shuffle(y_train)
xgb = XGBClassifier(scale_pos_weight=1/imbalance, learning_rate=0.2, n_estimators=500, max_depth=5,
                    n_jobs=cpus, use_label_encoder=False)
xgb.fit(X_train, y_train)
score_xgb = xgb.predict_proba(X_test)[:,1]
print('AUC:', roc_auc_score(y_test, score_xgb))
results = pd.DataFrame({'labels': y_test, 'scores': score_xgb})
results.to_csv(results_dir+'/v2.2/language_xgb_scores_random.csv', index=False)
# Out:
# [11:21:38] WARNING: /private/var/folders/p1/fvz7cyr12yl0lf647b14byy80000gn/T/pip-install-w5n3w6k9/xgboost_a8a36401f804426fb00f941f2eae565c/build/temp.macosx-11.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# AUC: 0.5167767890216484

# %% [markdown]
# #### Random Forest

# %%
rf = RandomForestClassifier(class_weight='balanced')
params_rf = {'n_estimators': [100, 250, 500, 750, 1000], 'max_features': ['auto', 0.05, 0.1, 0.2, 0.3]}
cv = StratifiedKFold(n_splits=5, shuffle=True)
cpus = 6

# %%
# do hyperparameter tuning (in GridSearchCV)
tuned_rf = GridSearchCV(rf, cv=cv, param_grid=params_rf, scoring='roc_auc', verbose=3)
tuned_rf.fit(X_train, y_train)
print(tuned_rf.best_params_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END max_features=auto, n_estimators=100;, score=0.902 total time=   4.3s
# [CV 2/5] END max_features=auto, n_estimators=100;, score=0.867 total time=   4.2s
# [CV 3/5] END max_features=auto, n_estimators=100;, score=0.806 total time=   4.1s
# [CV 4/5] END max_features=auto, n_estimators=100;, score=0.839 total time=   4.2s
# [CV 5/5] END max_features=auto, n_estimators=100;, score=0.882 total time=   4.1s
# [CV 1/5] END max_features=auto, n_estimators=250;, score=0.918 total time=   9.4s
# [CV 2/5] END max_features=auto, n_estimators=250;, score=0.841 total time=   9.2s
# [CV 3/5] END max_features=auto, n_estimators=250;, score=0.801 total time=   9.0s
# [CV 4/5] END max_features=auto, n_estimators=250;, score=0.841 total time=   9.4s
# [CV 5/5] END max_features=auto, n_estimators=250;, score=0.904 total time=   9.1s
# [CV 1/5] END max_features=auto, n_estimators=500;, score=0.927 total time=  18.1s
# [CV 2/5] END max_features=auto, n_estimators=500;, score=0.854 total time=  17.7s
# [CV 3/5] END max_features=auto, n_estimators=500;, score=0.813 total time=  17.5s
# [CV 4/5] END max_features=auto, n_estimators=500;, score=0.835 total time=  17.9s
# [CV 5/5] END max_features=auto, n_estimators=500;, score=0.884 total time=  17.6s
# [CV 1/5] END max_features=auto, n_estimators=750;, score=0.920 total time=  26.9s
# [CV 2/5] END max_features=auto, n_estimators=750;, score=0.856 total time=  26.0s
# [CV 3/5] END max_features=auto, n_estimators=750;, score=0.829 total time=  26.1s
# [CV 4/5] END max_features=auto, n_estimators=750;, score=0.840 total time=  26.5s
# [CV 5/5] END max_features=auto, n_estimators=750;, score=0.888 total time=  25.9s
# [CV 1/5] END max_features=auto, n_estimators=1000;, score=0.925 total time=  35.6s
# [CV 2/5] END max_features=auto, n_estimators=1000;, score=0.859 total time=  34.5s
# [CV 3/5] END max_features=auto, n_estimators=1000;, score=0.833 total time=  34.2s
# [CV 4/5] END max_features=auto, n_estimators=1000;, score=0.839 total time=  35.1s
# [CV 5/5] END max_features=auto, n_estimators=1000;, score=0.890 total time=  34.7s
# [CV 1/5] END max_features=0.05, n_estimators=100;, score=0.900 total time=   8.1s
# [CV 2/5] END max_features=0.05, n_estimators=100;, score=0.860 total time=   8.0s
# [CV 3/5] END max_features=0.05, n_estimators=100;, score=0.784 total time=   7.9s
# [CV 4/5] END max_features=0.05, n_estimators=100;, score=0.811 total time=   8.1s
# [CV 5/5] END max_features=0.05, n_estimators=100;, score=0.889 total time=   7.9s
# [CV 1/5] END max_features=0.05, n_estimators=250;, score=0.918 total time=  19.1s
# [CV 2/5] END max_features=0.05, n_estimators=250;, score=0.863 total time=  18.5s
# [CV 3/5] END max_features=0.05, n_estimators=250;, score=0.834 total time=  18.4s
# [CV 4/5] END max_features=0.05, n_estimators=250;, score=0.831 total time=  18.9s
# [CV 5/5] END max_features=0.05, n_estimators=250;, score=0.901 total time=  18.9s
# [CV 1/5] END max_features=0.05, n_estimators=500;, score=0.927 total time=  37.5s
# [CV 2/5] END max_features=0.05, n_estimators=500;, score=0.838 total time=  36.5s
# [CV 3/5] END max_features=0.05, n_estimators=500;, score=0.817 total time=  36.1s
# [CV 4/5] END max_features=0.05, n_estimators=500;, score=0.829 total time=  36.6s
# [CV 5/5] END max_features=0.05, n_estimators=500;, score=0.889 total time=  36.3s
# [CV 1/5] END max_features=0.05, n_estimators=750;, score=0.924 total time=  56.2s
# [CV 2/5] END max_features=0.05, n_estimators=750;, score=0.861 total time=  54.4s
# [CV 3/5] END max_features=0.05, n_estimators=750;, score=0.815 total time=  54.5s
# [CV 4/5] END max_features=0.05, n_estimators=750;, score=0.834 total time=  54.9s
# [CV 5/5] END max_features=0.05, n_estimators=750;, score=0.881 total time=  55.5s
# [CV 1/5] END max_features=0.05, n_estimators=1000;, score=0.922 total time= 1.3min
# [CV 2/5] END max_features=0.05, n_estimators=1000;, score=0.857 total time= 1.2min
# [CV 3/5] END max_features=0.05, n_estimators=1000;, score=0.823 total time= 1.2min
# [CV 4/5] END max_features=0.05, n_estimators=1000;, score=0.846 total time= 1.2min
# [CV 5/5] END max_features=0.05, n_estimators=1000;, score=0.896 total time= 1.2min
# [CV 1/5] END max_features=0.1, n_estimators=100;, score=0.903 total time=  15.4s
# [CV 2/5] END max_features=0.1, n_estimators=100;, score=0.844 total time=  15.1s
# [CV 3/5] END max_features=0.1, n_estimators=100;, score=0.803 total time=  14.8s
# [CV 4/5] END max_features=0.1, n_estimators=100;, score=0.827 total time=  14.7s
# [CV 5/5] END max_features=0.1, n_estimators=100;, score=0.846 total time=  14.5s
# [CV 1/5] END max_features=0.1, n_estimators=250;, score=0.917 total time=  36.1s
# [CV 2/5] END max_features=0.1, n_estimators=250;, score=0.857 total time=  34.9s
# [CV 3/5] END max_features=0.1, n_estimators=250;, score=0.813 total time=  34.5s
# [CV 4/5] END max_features=0.1, n_estimators=250;, score=0.814 total time=  35.0s
# [CV 5/5] END max_features=0.1, n_estimators=250;, score=0.884 total time=  34.7s
# [CV 1/5] END max_features=0.1, n_estimators=500;, score=0.913 total time= 1.2min
# [CV 2/5] END max_features=0.1, n_estimators=500;, score=0.864 total time= 1.1min
# [CV 3/5] END max_features=0.1, n_estimators=500;, score=0.815 total time= 1.1min
# [CV 4/5] END max_features=0.1, n_estimators=500;, score=0.832 total time= 1.2min
# [CV 5/5] END max_features=0.1, n_estimators=500;, score=0.883 total time= 1.2min
# [CV 1/5] END max_features=0.1, n_estimators=750;, score=0.916 total time= 1.8min
# [CV 2/5] END max_features=0.1, n_estimators=750;, score=0.848 total time= 1.7min
# [CV 3/5] END max_features=0.1, n_estimators=750;, score=0.822 total time= 1.7min
# [CV 4/5] END max_features=0.1, n_estimators=750;, score=0.823 total time= 1.7min
# [CV 5/5] END max_features=0.1, n_estimators=750;, score=0.881 total time= 1.7min
# [CV 1/5] END max_features=0.1, n_estimators=1000;, score=0.916 total time= 2.4min
# [CV 2/5] END max_features=0.1, n_estimators=1000;, score=0.856 total time= 2.3min
# [CV 3/5] END max_features=0.1, n_estimators=1000;, score=0.818 total time= 2.3min
# [CV 4/5] END max_features=0.1, n_estimators=1000;, score=0.837 total time= 2.3min
# [CV 5/5] END max_features=0.1, n_estimators=1000;, score=0.889 total time= 2.3min
# [CV 1/5] END max_features=0.2, n_estimators=100;, score=0.884 total time=  28.7s
# [CV 2/5] END max_features=0.2, n_estimators=100;, score=0.825 total time=  27.6s
# [CV 3/5] END max_features=0.2, n_estimators=100;, score=0.792 total time=  26.8s
# [CV 4/5] END max_features=0.2, n_estimators=100;, score=0.824 total time=  27.6s
# [CV 5/5] END max_features=0.2, n_estimators=100;, score=0.887 total time=  27.2s
# [CV 1/5] END max_features=0.2, n_estimators=250;, score=0.906 total time= 1.2min
# [CV 2/5] END max_features=0.2, n_estimators=250;, score=0.853 total time= 1.1min
# [CV 3/5] END max_features=0.2, n_estimators=250;, score=0.802 total time= 1.1min
# [CV 4/5] END max_features=0.2, n_estimators=250;, score=0.840 total time= 1.1min
# [CV 5/5] END max_features=0.2, n_estimators=250;, score=0.873 total time= 1.1min
# [CV 1/5] END max_features=0.2, n_estimators=500;, score=0.918 total time= 2.3min
# [CV 2/5] END max_features=0.2, n_estimators=500;, score=0.845 total time= 2.2min
# [CV 3/5] END max_features=0.2, n_estimators=500;, score=0.805 total time= 2.2min
# [CV 4/5] END max_features=0.2, n_estimators=500;, score=0.833 total time= 2.2min
# [CV 5/5] END max_features=0.2, n_estimators=500;, score=0.882 total time= 2.2min
# [CV 1/5] END max_features=0.2, n_estimators=750;, score=0.912 total time= 3.4min
# [CV 2/5] END max_features=0.2, n_estimators=750;, score=0.856 total time= 3.3min
# [CV 3/5] END max_features=0.2, n_estimators=750;, score=0.815 total time= 3.2min
# [CV 4/5] END max_features=0.2, n_estimators=750;, score=0.830 total time= 3.3min
# [CV 5/5] END max_features=0.2, n_estimators=750;, score=0.882 total time= 3.3min
# [CV 1/5] END max_features=0.2, n_estimators=1000;, score=0.912 total time= 4.5min
# [CV 2/5] END max_features=0.2, n_estimators=1000;, score=0.848 total time= 4.3min
# [CV 3/5] END max_features=0.2, n_estimators=1000;, score=0.805 total time= 4.3min
# [CV 4/5] END max_features=0.2, n_estimators=1000;, score=0.822 total time= 4.4min
# [CV 5/5] END max_features=0.2, n_estimators=1000;, score=0.879 total time= 4.3min
# [CV 1/5] END max_features=0.3, n_estimators=100;, score=0.884 total time=  40.7s
# [CV 2/5] END max_features=0.3, n_estimators=100;, score=0.846 total time=  39.7s
# [CV 3/5] END max_features=0.3, n_estimators=100;, score=0.781 total time=  38.8s
# [CV 4/5] END max_features=0.3, n_estimators=100;, score=0.836 total time=  39.3s
# [CV 5/5] END max_features=0.3, n_estimators=100;, score=0.853 total time=  39.5s
# [CV 1/5] END max_features=0.3, n_estimators=250;, score=0.904 total time= 1.7min
# [CV 2/5] END max_features=0.3, n_estimators=250;, score=0.847 total time= 1.6min
# [CV 3/5] END max_features=0.3, n_estimators=250;, score=0.810 total time= 1.6min
# [CV 4/5] END max_features=0.3, n_estimators=250;, score=0.820 total time= 1.6min
# [CV 5/5] END max_features=0.3, n_estimators=250;, score=0.883 total time= 1.6min
# [CV 1/5] END max_features=0.3, n_estimators=500;, score=0.909 total time= 3.4min
# [CV 2/5] END max_features=0.3, n_estimators=500;, score=0.854 total time= 3.2min
# [CV 3/5] END max_features=0.3, n_estimators=500;, score=0.801 total time= 3.2min
# [CV 4/5] END max_features=0.3, n_estimators=500;, score=0.831 total time= 3.3min
# [CV 5/5] END max_features=0.3, n_estimators=500;, score=0.869 total time= 3.3min
# [CV 1/5] END max_features=0.3, n_estimators=750;, score=0.902 total time= 5.1min
# [CV 2/5] END max_features=0.3, n_estimators=750;, score=0.868 total time= 4.9min
# [CV 3/5] END max_features=0.3, n_estimators=750;, score=0.816 total time= 4.8min
# [CV 4/5] END max_features=0.3, n_estimators=750;, score=0.828 total time= 4.9min
# [CV 5/5] END max_features=0.3, n_estimators=750;, score=0.878 total time= 4.9min
# [CV 1/5] END max_features=0.3, n_estimators=1000;, score=0.900 total time= 6.8min
# [CV 2/5] END max_features=0.3, n_estimators=1000;, score=0.851 total time= 6.5min
# [CV 3/5] END max_features=0.3, n_estimators=1000;, score=0.812 total time= 6.4min
# [CV 4/5] END max_features=0.3, n_estimators=1000;, score=0.838 total time= 6.6min
# [CV 5/5] END max_features=0.3, n_estimators=1000;, score=0.882 total time= 6.4min
# {'max_features': 0.05, 'n_estimators': 250}

# %%
# test set evaluation
rf = RandomForestClassifier(class_weight='balanced', n_estimators=250, max_features=0.05)
rf.fit(X_train, y_train)
score_rf = rf.predict_proba(X_test)[:,1]
print('AUC:', roc_auc_score(y_test, score_rf))
# Out:
# AUC: 0.8395759930394632

# %% [markdown]
# #### LOGOCV XGBoost over loci
#
# Basically, the idea is to do a LOGOCV with every locus being one group (so a total of ~200 groups). We won't do hyperparam optimization, as that would be too computationally intensive, but we will assume standard params except for the 500 estimators. Then, we can also compute MRR, because we know that each test set is in fact one query for which the probabilities can be ranked.

# %%
seros = pd.read_csv(valencia_dir+'/serotypes'+data_suffix+'.csv')

# %%
def mean_reciprocal_rank(queries):
    """
    This function computes the mean reciprocal rank for a given array or
    matrix of queries. It deals with relevant vs. non-relevant queries that are
    binary. If queries is a matrix, then it will compute the reciprocal ranks over
    all rows individually (for each 'query') and then average those.
    E.g.:
    queries = [[0, 0, 0], [0, 1, 0], [1, 0, 0]]
    mean_reciprocal_rank(queries) -> 0.5
    """
    queries = (np.asarray(r).nonzero()[0] for r in queries)
    return np.mean([1. / (r[0] + 1) if r.size else 0. for r in queries])

# %%
# do the LOGOCV
logo = LeaveOneGroupOut()
cpus = 6
auc_scores = []
ranked_queries = []
labels = np.asarray(labels)
sero_groups = []
pbar = tqdm(total=200)
for train_index, test_index in logo.split(features, labels, groups):
    # get the training and test data
    X_train, X_test = features[train_index], features[test_index]
    y_train, y_test = labels[train_index], labels[test_index]
    imbalance = sum([1 for i in y_train if i ==1]) / sum([1 for i in y_train if i ==0])

    # fit a XGBoost model
    xgb = XGBClassifier(scale_pos_weight=1/imbalance, n_estimators=500, n_jobs=cpus, eval_metric='logloss', 
                        use_label_encoder=False)
    xgb.fit(X_train, y_train)
    
    # make predictions
    score_xgb = xgb.predict_proba(X_test)[:,1]
    try:
        this_auc = roc_auc_score(y_test, score_xgb)
        auc_scores.append(this_auc)
        this_sero = seros['sero'][groups[test_index[0]]]
        sero_groups.append(this_sero) # get serotype linked to this test group
        print(this_sero, roc_auc_score(y_test, score_xgb))
        # sort labels to compute MRR later
        ranked_query = [x for _, x in sorted(zip(score_xgb, y_test), reverse=True)]
        ranked_queries.append(ranked_query)
        
    except:
        this_sero = seros['sero'][groups[test_index[0]]]
        print('No AUC/MRR computable for this sero: ', this_sero, test_index[0])
    
    # pbar update
    pbar.update(1)
pbar.close()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# K41 0.9272727272727272
# K15 0.10909090909090913
# K14 0.7019607843137254
# K43 0.5471698113207547
# K74 0.7685185185185185
# No AUC/MRR computable for this sero:  K5 280
# K62 0.6352941176470588
# No AUC/MRR computable for this sero:  K22 392
# K18 0.35185185185185186
# K74 0.8727272727272728
# No AUC/MRR computable for this sero:  K20 560
# K25 0.21818181818181814
# K46 0.23636363636363633
# K2 0.5454545454545454
# K68 0.9
# K11 0.8833333333333333
# K51 0.10909090909090913
# K34 0.9090909090909091
# K36 0.98
# No AUC/MRR computable for this sero:  K37 1064
# K29 0.9400000000000001
# K39 0.8703703703703703
# K31 1.0
# K61 0.4444444444444444
# K8 0.6923076923076923
# K80 0.8181818181818181
# K26 0.9748427672955975
# K47 0.9818181818181818
# K58 0.779874213836478
# K30 0.7672955974842768
# K32 0.9685534591194969
# K60 0.610062893081761
# No AUC/MRR computable for this sero:  K42 1792
# K63 0.19999999999999996
# K55 0.5733333333333333
# K13 0.7333333333333334
# K16 0.6111111111111112
# K59 0.4727272727272728
# K6 0.18181818181818177
# K64 0.91
# K65 0.9725490196078431
# K12 0.036363636363636376
# K49 0.37962962962962965
# K66 0.19999999999999996
# K35 0.5768321513002364
# No AUC/MRR computable for this sero:  K44 2520
# No AUC/MRR computable for this sero:  K19 2576
# No AUC/MRR computable for this sero:  K4 2632
# K33 0.5534591194968553
# K9 0.1454545454545455
# No AUC/MRR computable for this sero:  K82 2800
# K38 0.8653846153846154
# K50 0.8611111111111112
# K3 0.4
# K17 0.2962962962962963
# K57 0.7295597484276729
# No AUC/MRR computable for this sero:  K35 3136
# K10 0.2909090909090909
# K56 0.7400000000000001
# K54 0.7596153846153847
# K24 0.9166666666666666
# K1 0.6203703703703703
# unknown (KL134) 0.7441860465116279
# No AUC/MRR computable for this sero:  unknown (KL125) 3518
# No AUC/MRR computable for this sero:  K21 3564
# unknown (KL151) 1.0
# K25 1.0
# No AUC/MRR computable for this sero:  K35 3702
# K16 1.0
# No AUC/MRR computable for this sero:  unknown (KL111) 3794
# K13 1.0
# K62 1.0
# unknown (KL103) 1.0
# No AUC/MRR computable for this sero:  K39 3978
# No AUC/MRR computable for this sero:  K27 4024
# No AUC/MRR computable for this sero:  unknown (KL125) 4070
# K13 0.9659090909090908
# K13 1.0
# unknown (KL107) 0.9777777777777777
# K2 1.0
# No AUC/MRR computable for this sero:  unknown (KL128) 4300
# No AUC/MRR computable for this sero:  unknown (KL125) 4346
# No AUC/MRR computable for this sero:  K36 4392
# K2 1.0
# No AUC/MRR computable for this sero:  K31 4484
# No AUC/MRR computable for this sero:  K36 4530
# No AUC/MRR computable for this sero:  unknown (KL136) 4576
# K14 1.0
# K46 0.9777777777777777
# K14 1.0
# unknown (KL149) 0.3488372093023256
# No AUC/MRR computable for this sero:  unknown (KL153) 4806
# K37 1.0
# unknown (KL146) 1.0
# No AUC/MRR computable for this sero:  K38 4944
# No AUC/MRR computable for this sero:  unknown (KL128) 4990
# No AUC/MRR computable for this sero:  K7 5036
# unknown (KL151) 1.0
# No AUC/MRR computable for this sero:  K27 5128
# No AUC/MRR computable for this sero:  K36 5174
# No AUC/MRR computable for this sero:  unknown (KL107) 5220
# No AUC/MRR computable for this sero:  K17 5266
# No AUC/MRR computable for this sero:  K17 5312
# K81 0.8888888888888888
# No AUC/MRR computable for this sero:  unknown (KL105) 5404
# K39 1.0
# K20 1.0
# unknown (KL158) 0.9777777777777777
# No AUC/MRR computable for this sero:  K27 5588
# No AUC/MRR computable for this sero:  unknown (KL112) 5634
# No AUC/MRR computable for this sero:  unknown (KL139) 5680
# K30 0.7054263565891472
# No AUC/MRR computable for this sero:  K51 5772
# K31 1.0
# No AUC/MRR computable for this sero:  K17 5864
# K24 0.875
# K61 0.2015503875968992
# No AUC/MRR computable for this sero:  K27 6002
# No AUC/MRR computable for this sero:  K27 6048
# K10 0.7333333333333333
# K2 1.0
# unknown (KL140) 1.0
# No AUC/MRR computable for this sero:  K17 6232
# No AUC/MRR computable for this sero:  unknown (KL108) 6278
# K20 0.9659090909090908
# No AUC/MRR computable for this sero:  unknown (KL112) 6370
# unknown (KL102) 1.0
# No AUC/MRR computable for this sero:  K36 6462
# K39 1.0
# No AUC/MRR computable for this sero:  K21 6554
# K64 1.0
# No AUC/MRR computable for this sero:  K57 6646
# unknown (KL102) 1.0
# No AUC/MRR computable for this sero:  unknown (KL117) 6738
# K16 1.0
# No AUC/MRR computable for this sero:  K51 6830
# No AUC/MRR computable for this sero:  K36 6876
# No AUC/MRR computable for this sero:  K3 6922
# K13 1.0
# K16 1.0
# No AUC/MRR computable for this sero:  unknown (KL110) 7060
# K39 0.9777777777777777
# K25 0.5555555555555556
# No AUC/MRR computable for this sero:  unknown (KL105) 7198
# K3 0.8444444444444444
# K63 0.6201550387596899
# No AUC/MRR computable for this sero:  unknown (KL105) 7336
# unknown (KL122) 0.9555555555555556
# unknown (KL157) 0.1333333333333333
# No AUC/MRR computable for this sero:  K64 7474
# unknown (KL151) 0.761904761904762
# unknown (KL151) 0.7472527472527473
# K16 1.0
# K64 0.9777777777777777
# No AUC/MRR computable for this sero:  K46 7704
# K25 1.0
# No AUC/MRR computable for this sero:  K15 7796
# No AUC/MRR computable for this sero:  unknown (KL114) 7842
# No AUC/MRR computable for this sero:  unknown (KL105) 7888
# K13 1.0
# K1 1.0
# No AUC/MRR computable for this sero:  K1 8026
# K7 1.0
# K39 1.0
# No AUC/MRR computable for this sero:  K17 8164
# No AUC/MRR computable for this sero:  K12 8210
# unknown (KL140) 1.0
# No AUC/MRR computable for this sero:  K51 8302
# K36 1.0
# No AUC/MRR computable for this sero:  unknown (KL107) 8394
# unknown (KL140) 1.0
# K13 1.0
# No AUC/MRR computable for this sero:  unknown (KL127) 8532
# K62 1.0
# No AUC/MRR computable for this sero:  K5 8624
# K20 1.0
# No AUC/MRR computable for this sero:  unknown (KL112) 8716
# K14 1.0
# unknown (KL102) 1.0
# K13 0.9886363636363636
# K22 1.0
# K62 1.0
# No AUC/MRR computable for this sero:  K15 8992
# K25 1.0
# No AUC/MRR computable for this sero:  K24 9084
# K14 1.0
# unknown (KL102) 1.0
# No AUC/MRR computable for this sero:  unknown (KL107) 9222
# unknown (KL126) 0.3853658536585366
# No AUC/MRR computable for this sero:  K19 9314
# unknown (KL140) 1.0
# No AUC/MRR computable for this sero:  K24 9406
# No AUC/MRR computable for this sero:  K38 9452
# K46 1.0
# unknown (KL103) 1.0
# unknown (KL139) 0.0
# K1 1.0
# K1 0.8863636363636364
# unknown (KL102) 1.0
# No AUC/MRR computable for this sero:  K19 9774

# %%
# print results
print('AUC: ', np.mean(auc_scores))
print('MRR: ', mean_reciprocal_rank(ranked_queries))
# Out:
# AUC:  0.7934344392405449
# MRR:  0.6516745268978681

# %%
logo_results = pd.DataFrame({'sero': sero_groups, 'auc_scores': auc_scores, 'ranked_queries': ranked_queries})
logo_results.to_csv(results_dir+'/v2.2/language_xgb_logocv_results.csv', index=False)

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax.hist(auc_scores, bins=50)
ax.set_xlabel('ROC AUC score')
ax.set_ylabel('# of occurrences')
fig.savefig(results_dir+'/v2.2/language_xgb_logocv_AUChist.png', dpi=400)

# %% [markdown]
# ## X - Out of use

# %% [raw]
# # RANDOM SHUFFLE LABELS
# loci_sim = np.loadtxt(klebsiella_dir+'/kaptive_loci_score_matrix.txt')
# rf = RandomForestClassifier(n_estimators=200, class_weight='balanced', n_jobs=6)
# loci_cv = KFold(n_splits=10, shuffle=True)
# features = np.asarray(frame.iloc[:,:-4])
# labels = np.asarray(frame.iloc[:,-4])
# random.shuffle(labels)
#
# loci_list = []; rbps_list = []; scores_list = []
# for train_index, test_index in loci_cv.split(loci_sim):
#     print('new split')
#     # construct training and test dataframe
#     train_index_frame = []; test_index_frame = []
#     for i, row_id in enumerate(frame['row']):
#         if row_id in train_index:
#             train_index_frame.append(i)
#         else:
#             test_index_frame.append(i)
#     features_train, features_test = features[train_index_frame], features[test_index_frame]
#     labels_train, labels_test = labels[train_index_frame], labels[test_index_frame]
#
#     # fit a model
#     rf.fit(features_train, labels_train)
#
#     # make predictions
#     for test_i in tqdm(test_index_frame):
#         loci_nr = frame['row'][test_i]
#         rbp_nr = frame['col'][test_i]
#         score = rf.predict_proba(features[test_i].reshape(1,-1))[:,1]
#         loci_list.append(loci_nr)
#         rbps_list.append(rbp_nr)
#         scores_list.append(score[0])
#
# results = pd.DataFrame({'locus': loci_list, 'rbps': rbps_list, 'scores': scores_list})
# interaction_matrix_mono = np.asarray(pd.read_csv(klebsiella_dir+'/interactions_klebsiella_mono.csv', index_col=0))
# labels_random = [interaction_matrix_mono[results['locus'][i],results['rbps'][i]]
#              for i in range(results.shape[0])]
#
# ROCAUC = round(roc_auc_score(labels_random, results['scores']), 3)
# precision, recall, thresholds = precision_recall_curve(labels_random, results['scores'])
# PRAUC = round(auc(recall, precision), 3)
# print('ROCAUC: ', ROCAUC)
# print('PRAUC: ', PRAUC)

# %% [raw]
# def blast_local_python(file_name, data_dir):
#     """
#     This function does pairwise BLASTs between all sequences of an input FASTA file (Kaptive results)
#
#     Input:
#     - file_name: string of FASTA file to pairwise BLAST
#
#     To do:
#     - change to kaptive_file_names -> no big fasta needed, no need to make small fasta's first.
#     """
#
#     sequence_list = []
#     for record in SeqIO.parse(data_dir+'/'+file_name, 'fasta'):
#         sequence_list.append(str(record.seq))
#     score_matrix = np.zeros((len(sequence_list), len(sequence_list)))
#
#     for i in range(len(sequence_list)-1):
#         # make fasta sequence 1
#         fasta1 = open(data_dir+'/sequence1.fasta', 'w')
#         fasta1.write('>sequence1'+'\n'+sequence_list[i]+'\n')
#         fasta1.close()
#
#         for j in range(i, len(sequence_list)):
#             # make fasta sequence 2
#             fasta2 = open(data_dir+'/sequence2.fasta', 'w')
#             fasta2.write('>sequence2'+'\n'+sequence_list[j]+'\n')
#             fasta2.close()
#
#             # perform BLAST
#             blastp_cline = NcbiblastpCommandline(query=data_dir+'/sequence1.fasta', subject=data_dir+'/sequence2.fasta',
#                                                  evalue=10, outfmt=5, out=data_dir+'/BLAST_results.xml')
#             stdout, stderr = blastp_cline()
#
#             # get results
#             blast_result = open(data_dir+'/BLAST_results.xml')
#             blast_record = NCBIXML.read(blast_result)
#             try:
#                 alignment = blast_record.alignments[0]
#                 hsp = alignment.hsps[0]
#                 identity = (hsp.identities/hsp.align_length)*100
#             except IndexError:
#                 identity = 0
#                 pass
#
#             # write to score matrix
#             score_matrix[i,j] = identity
#
#     score_matrix = score_matrix + score_matrix.transpose()
#     score_matrix = score_matrix - np.diag(np.diag(score_matrix))
#
#     os.remove(data_dir+'/sequence1.fasta')
#     os.remove(data_dir+'/sequence2.fasta')
#
#     return score_matrix

# %% [raw]
# def locus_embeddings(kaptive_file_names, data_dir):
#     """
#     This functions computes Word2Vec embeddings for bacterial genomic loci. It uses the bio-embeddings
#     package together with BioPython to transform fasta sequences of bacterial loci into numerical embeddings.
#
#     WARNING: running this on a personal laptop without GPU can be slow (not advised). Best to start a Google
#     Colab notebook and run the computations in the cloud.
#
#     Input:
#     - kaptive_file_names: list of fasta filenames of bacterial loci (output of Kaptive)
#     - data_dir: location of the sequence file(s) to loop over
#     - results_dir: directory to store the resulting embeddings in.
#
#     Output:
#     - embeddings: Pandas DataFrame (as .csv file) with file names and their corresponding embedding
#     """
#     embedder = Word2VecEmbedder()
#     embeddings_list = []
#
#     for name in tqdm(kaptive_file_names):
#         locus_sequence = ''
#         # one or multiple records in fasta file
#         for record in SeqIO.parse(data_dir+'/'+name, 'fasta'):
#             locus_sequence += str(record.seq)
#
#         # compute embedding
#         embedding = embedder.embed(locus_sequence)
#         reduced_embedding = embedder.reduce_per_protein(embedding)
#         embeddings_list.append(reduced_embedding)
#
#     embeddings_df = pd.concat([pd.DataFrame(kaptive_file_names), pd.DataFrame(embeddings_list)], axis=1)
#     embeddings_df.to_csv(data_dir+'/locus_embeddings.csv', index=False)
#
#     return
